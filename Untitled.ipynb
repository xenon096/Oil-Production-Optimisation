# %%
import pandas as pnd
import numpy
from matplotlib import pyplot
file=pnd.read_excel('Volve production data.xlsx')

# %%
print(file.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15634 entries, 0 to 15633
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   15634 non-null  datetime64[ns]
#  1   WELL_BORE_CODE            15634 non-null  object
#  2   NPD_WELL_BORE_CODE        15634 non-null  int64
#  3   NPD_WELL_BORE_NAME        15634 non-null  object
#  4   NPD_FIELD_CODE            15634 non-null  int64
#  5   NPD_FIELD_NAME            15634 non-null  object
#  6   NPD_FACILITY_CODE         15634 non-null  int64
#  7   NPD_FACILITY_NAME         15634 non-null  object
#  8   ON_STREAM_HRS             15349 non-null  float64
#  9   AVG_DOWNHOLE_PRESSURE     8980 non-null   float64
#  10  AVG_DOWNHOLE_TEMPERATURE  8980 non-null   float64
#  11  AVG_DP_TUBING             8980 non-null   float64
#  12  AVG_ANNULUS_PRESS         7890 non-null   float64
# ...

# %%
#analysing the code per well with WELL_BORE_CODE
print(file['NPD_WELL_BORE_CODE'].value_counts())
# Out:
# 5693    3327
# 5769    3306
# 5599    3056
# 5351    3056
# 7078    1165
# 7289     978
# 7405     746
# Name: NPD_WELL_BORE_CODE, dtype: int64

# %%
# %matplotlib inline
pnd.plotting.scatter_matrix(file)
# Out:
# D:\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\misc.py:101: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# D:\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\misc.py:102: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# D:\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\misc.py:92: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(boundaries_list[i])
# array([[<Axes: xlabel='NPD_WELL_BORE_CODE', ylabel='NPD_WELL_BORE_CODE'>,
#         <Axes: xlabel='NPD_FIELD_CODE', ylabel='NPD_WELL_BORE_CODE'>,
#         <Axes: xlabel='NPD_FACILITY_CODE', ylabel='NPD_WELL_BORE_CODE'>,
#         <Axes: xlabel='ON_STREAM_HRS', ylabel='NPD_WELL_BORE_CODE'>,
# ...

# %%
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#5599
w2=file['NPD_WELL_BORE_CODE']==5599
file_w2=file[w2]
print(file_w2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3056 entries, 1911 to 4966
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   3056 non-null   datetime64[ns]
#  1   WELL_BORE_CODE            3056 non-null   object
#  2   NPD_WELL_BORE_CODE        3056 non-null   int64
#  3   NPD_WELL_BORE_NAME        3056 non-null   object
#  4   NPD_FIELD_CODE            3056 non-null   int64
#  5   NPD_FIELD_NAME            3056 non-null   object
#  6   NPD_FACILITY_CODE         3056 non-null   int64
#  7   NPD_FACILITY_NAME         3056 non-null   object
#  8   ON_STREAM_HRS             3056 non-null   float64
#  9   AVG_DOWNHOLE_PRESSURE     3050 non-null   float64
#  10  AVG_DOWNHOLE_TEMPERATURE  3050 non-null   float64
#  11  AVG_DP_TUBING             3050 non-null   float64
#  12  AVG_ANNULUS_PRESS         3043 non-null   float64
# ...

# %%
#well numbers:5693,5769,5599,5351,7078,7289,7405
#5693
w1=file['NPD_WELL_BORE_CODE']==5693
file_w1=file[w1]
print(file_w1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3327 entries, 9001 to 12327
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   3327 non-null   datetime64[ns]
#  1   WELL_BORE_CODE            3327 non-null   object
#  2   NPD_WELL_BORE_CODE        3327 non-null   int64
#  3   NPD_WELL_BORE_NAME        3327 non-null   object
#  4   NPD_FIELD_CODE            3327 non-null   int64
#  5   NPD_FIELD_NAME            3327 non-null   object
#  6   NPD_FACILITY_CODE         3327 non-null   int64
#  7   NPD_FACILITY_NAME         3327 non-null   object
#  8   ON_STREAM_HRS             3175 non-null   float64
#  9   AVG_DOWNHOLE_PRESSURE     0 non-null      float64
#  10  AVG_DOWNHOLE_TEMPERATURE  0 non-null      float64
#  11  AVG_DP_TUBING             0 non-null      float64
#  12  AVG_ANNULUS_PRESS         0 non-null      float64
# ...

# %%
#5769
w3=file['NPD_WELL_BORE_CODE']==5769
file_w3=file[w3]
print(file_w3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3306 entries, 12328 to 15633
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   3306 non-null   datetime64[ns]
#  1   WELL_BORE_CODE            3306 non-null   object
#  2   NPD_WELL_BORE_CODE        3306 non-null   int64
#  3   NPD_WELL_BORE_NAME        3306 non-null   object
#  4   NPD_FIELD_CODE            3306 non-null   int64
#  5   NPD_FIELD_NAME            3306 non-null   object
#  6   NPD_FACILITY_CODE         3306 non-null   int64
#  7   NPD_FACILITY_NAME         3306 non-null   object
#  8   ON_STREAM_HRS             3173 non-null   float64
#  9   AVG_DOWNHOLE_PRESSURE     0 non-null      float64
#  10  AVG_DOWNHOLE_TEMPERATURE  0 non-null      float64
#  11  AVG_DP_TUBING             0 non-null      float64
#  12  AVG_ANNULUS_PRESS         160 non-null    float64
# ...

# %%
#5351
w4=file['NPD_WELL_BORE_CODE']==5351
file_w4=file[w4]
print(file_w4.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3056 entries, 4967 to 8022
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   3056 non-null   datetime64[ns]
#  1   WELL_BORE_CODE            3056 non-null   object
#  2   NPD_WELL_BORE_CODE        3056 non-null   int64
#  3   NPD_WELL_BORE_NAME        3056 non-null   object
#  4   NPD_FIELD_CODE            3056 non-null   int64
#  5   NPD_FIELD_NAME            3056 non-null   object
#  6   NPD_FACILITY_CODE         3056 non-null   int64
#  7   NPD_FACILITY_NAME         3056 non-null   object
#  8   ON_STREAM_HRS             3056 non-null   float64
#  9   AVG_DOWNHOLE_PRESSURE     3050 non-null   float64
#  10  AVG_DOWNHOLE_TEMPERATURE  3050 non-null   float64
#  11  AVG_DP_TUBING             3050 non-null   float64
#  12  AVG_ANNULUS_PRESS         2533 non-null   float64
# ...

# %%
#7078
w5=file['NPD_WELL_BORE_CODE']==7078
file_w5=file[w5]
print(file_w5.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1165 entries, 746 to 1910
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   1165 non-null   datetime64[ns]
#  1   WELL_BORE_CODE            1165 non-null   object
#  2   NPD_WELL_BORE_CODE        1165 non-null   int64
#  3   NPD_WELL_BORE_NAME        1165 non-null   object
#  4   NPD_FIELD_CODE            1165 non-null   int64
#  5   NPD_FIELD_NAME            1165 non-null   object
#  6   NPD_FACILITY_CODE         1165 non-null   int64
#  7   NPD_FACILITY_NAME         1165 non-null   object
#  8   ON_STREAM_HRS             1165 non-null   float64
#  9   AVG_DOWNHOLE_PRESSURE     1159 non-null   float64
#  10  AVG_DOWNHOLE_TEMPERATURE  1159 non-null   float64
#  11  AVG_DP_TUBING             1159 non-null   float64
#  12  AVG_ANNULUS_PRESS         1159 non-null   float64
# ...

# %%
#7289
w6=file['NPD_WELL_BORE_CODE']==7289
file_w6=file[w6]
print(file_w6.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 978 entries, 8023 to 9000
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   978 non-null    datetime64[ns]
#  1   WELL_BORE_CODE            978 non-null    object
#  2   NPD_WELL_BORE_CODE        978 non-null    int64
#  3   NPD_WELL_BORE_NAME        978 non-null    object
#  4   NPD_FIELD_CODE            978 non-null    int64
#  5   NPD_FIELD_NAME            978 non-null    object
#  6   NPD_FACILITY_CODE         978 non-null    int64
#  7   NPD_FACILITY_NAME         978 non-null    object
#  8   ON_STREAM_HRS             978 non-null    float64
#  9   AVG_DOWNHOLE_PRESSURE     978 non-null    float64
#  10  AVG_DOWNHOLE_TEMPERATURE  978 non-null    float64
#  11  AVG_DP_TUBING             978 non-null    float64
#  12  AVG_ANNULUS_PRESS         978 non-null    float64
# ...

# %%
#7405
w7=file['NPD_WELL_BORE_CODE']==7405
file_w7=file[w7]
print(file_w7.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 746 entries, 0 to 745
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   746 non-null    datetime64[ns]
#  1   WELL_BORE_CODE            746 non-null    object
#  2   NPD_WELL_BORE_CODE        746 non-null    int64
#  3   NPD_WELL_BORE_NAME        746 non-null    object
#  4   NPD_FIELD_CODE            746 non-null    int64
#  5   NPD_FIELD_NAME            746 non-null    object
#  6   NPD_FACILITY_CODE         746 non-null    int64
#  7   NPD_FACILITY_NAME         746 non-null    object
#  8   ON_STREAM_HRS             746 non-null    float64
#  9   AVG_DOWNHOLE_PRESSURE     743 non-null    float64
#  10  AVG_DOWNHOLE_TEMPERATURE  743 non-null    float64
#  11  AVG_DP_TUBING             743 non-null    float64
#  12  AVG_ANNULUS_PRESS         17 non-null     float64
# ...

# %%
import numpy
from matplotlib import pyplot
# %matplotlib inline
pyplot.style.use('ggplot')
#Emperical Cumulative Distribution Function
def emperical(data):
    n=len(data)
    x=numpy.sort(data)
    y=numpy.arange(1,n+1)/n
    return x,y

#---------------------------------------------------
#w7
x,y=emperical(file_w7['BORE_OIL_VOL'])
pyplot.plot(x,y,marker='.',linestyle='none')
#labeling
pyplot.title('Bore no:7405(w7)')
pyplot.xlabel('Volume(Sm3)')
pyplot.ylabel('Distribution')

pyplot.show()

# %%
#w2
x,y=emperical(file_w2['BORE_OIL_VOL'])
pyplot.plot(x,y,marker=".",linestyle='none')
#label
pyplot.xlabel('Volume(sm3)')
pyplot.ylabel('Distribution')
pyplot.title('Bore no:5599(w2)')

pyplot.show()

# %%
#w1
x,y=emperical(file_w1['BORE_OIL_VOL'])
pyplot.plot(x,y,marker='.',linestyle='none')
#label
pyplot.xlabel('Volume(sm3)')
pyplot.ylabel('Distribution')
pyplot.title('Bore no:5693(w1)')

pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 3
#       1 #w1
#       2 x,y=emperical(file_w1['BORE_OIL_VOL'])
# ----> 3 pyplot.plot(x,y,marker='.',linestyle='none')
#       4 #label
#       5 pyplot.xlabel('Volume(sm3)')
#
# File D:\Anaconda\lib\site-packages\matplotlib\pyplot.py:2785, in plot(scalex, scaley, data, *args, **kwargs)
#    2783 @_copy_docstring_and_deprecators(Axes.plot)
#    2784 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2785     return gca().plot(
#    2786         *args, scalex=scalex, scaley=scaley,
#    2787         **({"data": data} if data is not None else {}), **kwargs)
#
# File D:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py:1690, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
# ...

# %%
#As there are no consistant values for the Oil Volume let's take Waterinjection level
#w1_waterlevel
x,y = emperical(file_w1['BORE_WI_VOL'])
pyplot.plot(x,y,marker='.',linestyle="none")
#Label
pyplot.xlabel('Water Injection(sm3)')
pyplot.ylabel('Distribution')
pyplot.title('Bore no:5769(w1)')

pyplot.show()

# %%
#w3_volume
x,y=emperical(file_w3['BORE_OIL_VOL'])
pyplot.plot(x,y,marker='.',linestyle='none')
#label
pyplot.xlabel('Volume(sm3)')
pyplot.ylabel('Distribution')
pyplot.title('No:5769(w3)')

pyplot.show()

# %%
#as w3's data is uneven we'll take its water injection
#w3_waterlevel
x,y=emperical(file_w3['BORE_WI_VOL'])
pyplot.plot(x,y,marker=".",linestyle="none")
#label
pyplot.xlabel('Water Injection(sm3)')
pyplot.ylabel('Distribution')
pyplot.title('no:5769(w3)')

pyplot.show()

# %%
#w4_volume
x,y=emperical(file_w4['BORE_OIL_VOL'])
pyplot.plot(x,y,marker='.',linestyle='none')
#label
pyplot.xlabel('Volume(sm3)')
pyplot.ylabel('Distribution')
pyplot.title('No:5351(w4)')

pyplot.show()

# %%
#w5_volume
x,y=emperical(file_w5['BORE_OIL_VOL'])
pyplot.plot(x,y,marker='.',linestyle='none')
#label
pyplot.xlabel('Volume(sm3)')
pyplot.ylabel('Distribution')
pyplot.title('No:7078(w5)')

pyplot.show()

# %%
#w6_volume
x,y=emperical(file_w6['BORE_OIL_VOL'])
pyplot.plot(x,y,marker='.',linestyle='none')
#label
pyplot.xlabel('Volume(sm3)')
pyplot.ylabel('Distribution')
pyplot.title('No:7289(w6)')

pyplot.show()

# %%
#getting info of all float values
dtfiles=file.select_dtypes(include='float')
print(dtfiles.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15634 entries, 0 to 15633
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ON_STREAM_HRS             15349 non-null  float64
#  1   AVG_DOWNHOLE_PRESSURE     8980 non-null   float64
#  2   AVG_DOWNHOLE_TEMPERATURE  8980 non-null   float64
#  3   AVG_DP_TUBING             8980 non-null   float64
#  4   AVG_ANNULUS_PRESS         7890 non-null   float64
#  5   AVG_CHOKE_SIZE_P          8919 non-null   float64
#  6   AVG_WHP_P                 9155 non-null   float64
#  7   AVG_WHT_P                 9146 non-null   float64
#  8   DP_CHOKE_SIZE             15340 non-null  float64
#  9   BORE_OIL_VOL              9161 non-null   float64
#  10  BORE_GAS_VOL              9161 non-null   float64
#  11  BORE_WAT_VOL              9161 non-null   float64
#  12  BORE_WI_VOL               5706 non-null   float64
# dtypes: float64(13)
# ...

# %%
#gaining the values of axis for all factors to find reduncency using seaborn
import seaborn
seaborn.heatmap(dtfiles.corr(),square=True,cmap='RdYlGn')
# Out:
# <Axes: >

# %%
#getting the __dict__ value of floating values of attributes
print(dtfiles.var())
# Out:
# ON_STREAM_HRS               7.005654e+01
# AVG_DOWNHOLE_PRESSURE       1.203680e+04
# AVG_DOWNHOLE_TEMPERATURE    2.084648e+03
# AVG_DP_TUBING               5.890927e+03
# AVG_ANNULUS_PRESS           7.067466e+01
# AVG_CHOKE_SIZE_P            1.346371e+03
# AVG_WHP_P                   6.126927e+02
# AVG_WHT_P                   7.683445e+02
# DP_CHOKE_SIZE               3.927106e+02
# BORE_OIL_VOL                1.751753e+06
# BORE_GAS_VOL                3.539531e+10
# BORE_WAT_VOL                2.913790e+06
# BORE_WI_VOL                 4.758884e+06
# dtype: float64

# %%
#Plotting boxplots for all the main features to visualize the distribution of data
#%matplotlib notebook
fs = (9,4)
pyplot.figure(figsize=fs)
seaborn.boxplot(x='NPD_WELL_BORE_CODE',y='ON_STREAM_HRS',data=file)

pyplot.figure(figsize=fs)
seaborn.boxplot(x='NPD_WELL_BORE_CODE', y='AVG_DOWNHOLE_PRESSURE',data=file)

pyplot.figure(figsize=fs)
seaborn.boxplot(x='NPD_WELL_BORE_CODE',y='AVG_DOWNHOLE_TEMPERATURE',data=file)

pyplot.figure(figsize=fs)
seaborn.boxplot(x='NPD_WELL_BORE_CODE', y='AVG_DP_TUBING',data=file)

pyplot.figure(figsize=fs)
seaborn.boxplot(x='NPD_WELL_BORE_CODE',y='AVG_ANNULUS_PRESS',data=file)

pyplot.figure(figsize=fs)
seaborn.boxplot(x='NPD_WELL_BORE_CODE',y='AVG_CHOKE_SIZE_P',data=file)

pyplot.figure(figsize=fs)
seaborn.boxplot(x='NPD_WELL_BORE_CODE',y='AVG_WHP_P',data=file)

pyplot.figure(figsize=fs)
seaborn.boxplot(x='NPD_WELL_BORE_CODE',y='AVG_WHT_P',data=file)

pyplot.figure(figsize=fs)
seaborn.boxplot(x='NPD_WELL_BORE_CODE',y='DP_CHOKE_SIZE',data=file)

pyplot.figure(figsize=fs)
seaborn.boxplot(x='NPD_WELL_BORE_CODE',y='BORE_OIL_VOL',data=file)

pyplot.figure(figsize=fs)
seaborn.boxplot(x='NPD_WELL_BORE_CODE',y='BORE_GAS_VOL',data=file)

pyplot.figure(figsize=fs)
seaborn.boxplot(x='NPD_WELL_BORE_CODE',y='BORE_WAT_VOL',data=file)

pyplot.figure(figsize=fs)
seaborn.boxplot(x='NPD_WELL_BORE_CODE',y='BORE_WI_VOL',data=file)
# Out:
# <Axes: xlabel='NPD_WELL_BORE_CODE', ylabel='BORE_WI_VOL'>

# %%
#round off values of data for integer
file=numpy.round(file)

# %%
#as the given data is skewed witn null values-- padding them(Forward Filling)
file['ON_STREAM_HRS'] = file['ON_STREAM_HRS'].fillna(method='pad')

file['AVG_DOWNHOLE_PRESSURE'] = file['AVG_DOWNHOLE_PRESSURE'].fillna(method='pad')

file['AVG_DOWNHOLE_TEMPERATURE'] = file['AVG_DOWNHOLE_TEMPERATURE'].fillna(method='pad')

file['AVG_DP_TUBING'] = file['AVG_DP_TUBING'].fillna(method='pad')

file['AVG_ANNULUS_PRESS'] = file['AVG_ANNULUS_PRESS'].fillna(method='pad')

file['AVG_CHOKE_SIZE_P'] = file['AVG_CHOKE_SIZE_P'].fillna(method='pad')

file['AVG_WHP_P'] = file['AVG_WHP_P'].fillna(method='pad')

file['AVG_WHT_P'] = file['AVG_WHT_P'].fillna(method='pad')

file['DP_CHOKE_SIZE'] = file['DP_CHOKE_SIZE'].fillna(method='pad')

file['BORE_OIL_VOL'] = file['BORE_OIL_VOL'].fillna(method='pad')

file['BORE_GAS_VOL'] = file['BORE_GAS_VOL'].fillna(method='pad')

file['BORE_WAT_VOL'] = file['BORE_WAT_VOL'].fillna(method='pad')

# %%
#Removing difference in distribution in columns to scale dataset
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
file[['ON_STREAM_HRS','AVG_DOWNHOLE_TEMPERATURE','AVG_ANNULUS_PRESS','AVG_CHOKE_SIZE_P','AVG_WHP_P','AVG_WHT_P']] = scaler.fit_transform(file[['ON_STREAM_HRS', 'AVG_DOWNHOLE_TEMPERATURE','AVG_ANNULUS_PRESS', 'AVG_CHOKE_SIZE_P','AVG_WHP_P', 'AVG_WHT_P']])
#Taking the data of wells:5693 & 5769 since they were the ones with more number of missing values
ff=file.loc[746:8022]

x=ff.drop(['BORE_OIL_VOL'],axis=1)
y= ff[['BORE_OIL_VOL','NPD_WELL_BORE_CODE']]
#Applying Linear Regression
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

L_reg=LinearRegression()

# %%
#gaining date values of daily production
print(file.DATEPRD)
# Out:
# 0       2014-04-07
# 1       2014-04-08
# 2       2014-04-09
# 3       2014-04-10
# 4       2014-04-11
#            ...
# 15629   2016-09-14
# 15630   2016-09-15
# 15631   2016-09-16
# 15632   2016-09-17
# 15633   2016-09-18
# Name: DATEPRD, Length: 15634, dtype: datetime64[ns]

# %%
#now taking the dates of production for training the data on daily basis for x variable
final_x_train=x_train.drop(['DATEPRD','NPD_WELL_BORE_CODE'],axis=1)
final_x_test=x_test.drop(['DATEPRD',"NPD_WELL_BORE_CODE"],axis=1)

# %%
#taking the dates of production for training the data on daily basis for y variable
final_y_train=y_train['BORE_OIL_VOL']
final_y_test=y_test['BORE_OIL_VOL']

# %%
#gaining x,y variables of the data collected on wells 5693,5769
x=ff.drop(['DATEPRD','BORE_OIL_VOL'],axis=1).values
y=ff['BORE_OIL_VOL']

# %%
#getting final x trained value
final_x_train
# Out:
#       ON_STREAM_HRS  AVG_DOWNHOLE_TEMPERATURE  AVG_ANNULUS_PRESS  \
# 3374           0.96                  0.000000           0.433333
# 3760           0.96                  0.000000           0.500000
# 2900           0.96                  0.000000           0.766667
# 2090           0.96                  0.972477           0.400000
# 7782           0.96                  0.917431           0.466667
# ...             ...                       ...                ...
# 5937           0.96                  0.972477           0.000000
# 5972           0.96                  0.972477           0.000000
# 6136           0.92                  0.954128           0.000000
# 1606           0.96                  0.972477           0.366667
# 8016           0.00                  0.000000           0.366667
#
#       AVG_CHOKE_SIZE_P  AVG_WHP_P  AVG_WHT_P  DP_CHOKE_SIZE  BORE_WAT_VOL
# 3374              1.00   0.248175   0.978723            5.0        4663.0
# ...

# %%
#regression of x,y trained data 
L_reg.fit(final_x_train,final_y_train)
# Out:
# LinearRegression()

# %%
#prediction of y variable with R2 linear regression trained x test value
pred_y=L_reg.predict(final_x_test)

# %%
print('R2 linear regression for oil volume production:',L_reg.score(final_x_test,final_y_test))
# Out:
# R2 linear regression for oil volume production: 0.5542109655694203

# %%
#getting count with enumerate to get summary of the given regression with coef_
stat=L_reg.coef_

for k,v in enumerate(stat):
    print('No:%d, score:%.5f'%(k,v))
# Out:
# No:0, score:1338.07639
# No:1, score:280.89200
# No:2, score:-1194.43707
# No:3, score:48.02134
# No:4, score:506.57085
# No:5, score:2572.30477
# No:6, score:13.05541
# No:7, score:-0.40973

# %%
L_reg.coef_
# Out:
# array([ 1.33807639e+03,  2.80892004e+02, -1.19443707e+03,  4.80213352e+01,
#         5.06570847e+02,  2.57230477e+03,  1.30554129e+01, -4.09730530e-01])

# %%
#having data intercept value
L_reg.intercept_
# Out:
# -1110.7026986608378

# %%
#get attribute relation in linear regression
print("correlation in linear regression :\nBORE_OIL_VOL:{:.5}+{:.5}*\nON_STREAM_HRS:+{:.5}*\nAVG_DOWNHOLE_TEMPERATURE:{:.5}*\nAVG_ANNULUS_PRESS:+{:.5}*\nAVG_CHOKE_SIZE_P:+{:.5}*\nAVG_WHP_P:+{:.5}*\nAVG_WHT_P:+{:.5}*\nDP_CHOKE_SIZE:{:.5}*\nBORE_WAT_".format(L_reg.intercept_,L_reg.coef_[0],L_reg.coef_[1],L_reg.coef_[2],L_reg.coef_[3],L_reg.coef_[4],L_reg.coef_[5],L_reg.coef_[6],L_reg.coef_[7]))
# Out:
# correlation in linear regression :
# BORE_OIL_VOL:-1110.7+1338.1*
# ON_STREAM_HRS:+280.89*
# AVG_DOWNHOLE_TEMPERATURE:-1194.4*
# AVG_ANNULUS_PRESS:+48.021*
# AVG_CHOKE_SIZE_P:+506.57*
# AVG_WHP_P:+2572.3*
# AVG_WHT_P:+13.055*
# DP_CHOKE_SIZE:-0.40973*
# BORE_WAT_

# %%
#----------------------------------

#now performing Polynomial Regression
from sklearn.preprocessing import PolynomialFeatures
p_reg=PolynomialFeatures(degree=4)
poly_x=p_reg.fit_transform(final_x_train)
l_reg=LinearRegression()
l_reg.fit(poly_x,final_y_train)
p_x_test=p_reg.fit_transform(final_x_test)
poly_x.shape[1]
# Out:
# 495

# %%
arr=numpy.array(p_reg.get_feature_names_out(['ON_STREAM_HRS','AVG_DOWNHOLE_TEMPERATURE', 'AVG_ANNULUS_PRESS', 'AVG_CHOKE_SIZE_P','AVG_WHP_P','AVG_WHT_P','DP_CHOKE_SIZE' ,'BORE_WAT_VOL']))

# %%
print(len(arr))
# Out:
# 495

# %%
x=numpy.array(l_reg.coef_)

# %%
#get corelation of polynomial&linear in DAtaframe
poly_rel=pnd.DataFrame({'Coeff':x,'Attribure':arr})
pnd.set_option('display.max_rows',30)
poly_rel.head(30)
# Out:
#         Coeff                                   Attribure
# 0   12.930439                                           1
# 1   45.784850                               ON_STREAM_HRS
# 2  -20.387934                    AVG_DOWNHOLE_TEMPERATURE
# 3  -79.511454                           AVG_ANNULUS_PRESS
# 4   71.656354                            AVG_CHOKE_SIZE_P
# 5   27.630158                                   AVG_WHP_P
# 6   42.764691                                   AVG_WHT_P
# 7  -17.551961                               DP_CHOKE_SIZE
# 8   23.656890                                BORE_WAT_VOL
# 9   99.828211                             ON_STREAM_HRS^2
# 10  54.135495      ON_STREAM_HRS AVG_DOWNHOLE_TEMPERATURE
# 11  25.732636             ON_STREAM_HRS AVG_ANNULUS_PRESS
# 12  92.506524              ON_STREAM_HRS AVG_CHOKE_SIZE_P
# 13  15.500355                     ON_STREAM_HRS AVG_WHP_P
# 14  63.138591                     ON_STREAM_HRS AVG_WHT_P
# ...

# %%
#getting count with enumerate regression with coef_
st=l_reg.coef_

for k,v in enumerate(st):
    print('No:%d, score:%.5f'%(k,v))
# Out:
# No:0, score:12.93044
# No:1, score:45.78485
# No:2, score:-20.38793
# No:3, score:-79.51145
# No:4, score:71.65635
# No:5, score:27.63016
# No:6, score:42.76469
# No:7, score:-17.55196
# No:8, score:23.65689
# No:9, score:99.82821
# No:10, score:54.13550
# No:11, score:25.73264
# No:12, score:92.50652
# No:13, score:15.50036
# No:14, score:63.13859
# No:15, score:27.51393
# No:16, score:-11.49192
# No:17, score:-26.00128
# No:18, score:-27.61504
# No:19, score:29.53354
# No:20, score:5.08632
# No:21, score:-11.09202
# No:22, score:77.67918
# No:23, score:-20.00334
# No:24, score:-74.29900
# No:25, score:26.42041
# No:26, score:-0.34121
# No:27, score:-10.54301
# No:28, score:66.10100
# No:29, score:-8.34744
# No:30, score:65.50718
# No:31, score:17.19764
# No:32, score:63.79879
# No:33, score:31.09337
# No:34, score:38.38342
# No:35, score:21.51843
# No:36, score:10.12742
# No:37, score:8.68607
# No:38, score:56.23042
# No:39, score:21.92123
# No:40, score:-39.87794
# ...

# %%
pyplot.figure(figsize=(12,8))
pyplot.xlabel('Bore No')
pyplot.ylabel('Coefficient of comparison')
pyplot.bar([x for x in range(len(st))],st)
pyplot.show()

# %%
#prediction in y axis
pred_y=l_reg.predict(p_x_test)

print("R2 value in Polynomial regression(4th order) for oil volume:",l_reg.score(p_x_test,final_y_test))
# Out:
# R2 value in Polynomial regression(4th order) for oil volume: 0.9360795685981668

# %%
file=pnd.DataFrame({'Real Values':final_y_test,'Predicted Values':pred_y})
file.head(50)
# Out:
#       Real Values  Predicted Values
# 6805        643.0       -199.113741
# 6756        613.0        442.093122
# 5221       4634.0       4451.431362
# 4435        688.0        758.376214
# 5261       3571.0       3524.177770
# ...           ...               ...
# 6176        928.0       1776.564046
# 4404        719.0        523.116247
# 4942          0.0       -114.467412
# 3628        575.0        354.206141
# 7692        181.0         82.400334
#
# [50 rows x 2 columns]

# %%
x_test.groupby(['NPD_WELL_BORE_CODE']).agg({"DATEPRD":"count"})
# Out:
#                     DATEPRD
# NPD_WELL_BORE_CODE
# 5351                    910
# 5599                    914
# 7078                    360

# %%
###we can see that the linear regression of 5693 is null
#hence similarly we can also see that 5769,7289,7405 also has null values because of water injection

# %%
#planning linear regression for w3:5599
x_test_5599=x_test[x_test['NPD_WELL_BORE_CODE']==5599]
y_test_5599=y_test[y_test["NPD_WELL_BORE_CODE"]==5599]

x_testfinal5599=x_test_5599.drop(['DATEPRD','NPD_WELL_BORE_CODE'],axis=1)

pred_y=L_reg.predict(x_testfinal5599)
#using pyplot style 'fivethirtyeight' to compare distribution
pyplot.style.use('fivethirtyeight')
pyplot.figure(figsize=(12,8))
pyplot.scatter(x_test_5599["DATEPRD"].tolist(),pred_y,label='predicted')
pyplot.scatter(x_test_5599["DATEPRD"].tolist(),y_test_5599['BORE_OIL_VOL'],label='actual')
pyplot.legend()
pyplot.xlabel("Year")
pyplot.ylabel("oil volume")
pyplot.title('ACtual vs linear regression forecast of oil production for bore:5599')

y_testfinal5599=y_test_5599['BORE_OIL_VOL']
print('R2 Value of Linear regression in Volume in 5693:',L_reg.score(x_testfinal5599,y_testfinal5599))
# Out:
# R2 Value of Linear regression in Volume in 5693: 0.55008329388721

# %%
print("The linear model is: BORE_OIL_VOL = {:.5} + {:.5}*\nON_STREAM_HRS + {:.5}*\nAVG_DOWNHOLE_TEMPERATURE  {:.5}*\nAVG_ANNULUS_PRESS + {:.5}*\nAVG_CHOKE_SIZE_P + {:.5}*\nAVG_WHP_P + {:.5}*\nAVG_WHT_P + {:.5}*\nDP_CHOKE_SIZE {:.5}*\nBORE_WAT_".format(L_reg.intercept_,L_reg.coef_[0],L_reg.coef_[1],L_reg.coef_[2],L_reg.coef_[3],L_reg.coef_[4],L_reg.coef_[5],L_reg.coef_[6],L_reg.coef_[7]))
# Out:
# The linear model is: BORE_OIL_VOL = -1110.7 + 1338.1*
# ON_STREAM_HRS + 280.89*
# AVG_DOWNHOLE_TEMPERATURE  -1194.4*
# AVG_ANNULUS_PRESS + 48.021*
# AVG_CHOKE_SIZE_P + 506.57*
# AVG_WHP_P + 2572.3*
# AVG_WHT_P + 13.055*
# DP_CHOKE_SIZE -0.40973*
# BORE_WAT_

# %%
#planning linear regression for w3:5599
x_test_5599=x_test[x_test['NPD_WELL_BORE_CODE']==5599]
y_test_5599=y_test[y_test["NPD_WELL_BORE_CODE"]==5599]

x_testfinal5599=x_test_5599.drop(['DATEPRD','NPD_WELL_BORE_CODE'],axis=1)

pred_y=L_reg.predict(x_testfinal5599)

#pol test 5599 regression values
p_x_test5599=p_reg.fit_transform(x_testfinal5599)
pol_y=l_reg.predict(p_x_test5599)

#using pyplot style 'fivethirtyeight' to compare distribution
pyplot.style.use('fivethirtyeight')
pyplot.figure(figsize=(12,8))
pyplot.scatter(x_test_5599["DATEPRD"].tolist(),pred_y,label='Linear predicted',color='blue')
pyplot.scatter(x_test_5599["DATEPRD"].tolist(),pol_y,label='Polynomial',color='red')

pyplot.scatter(x_test_5599["DATEPRD"].tolist(),y_test_5599['BORE_OIL_VOL'],label='actual',color='green')
pyplot.legend()
pyplot.xlabel("Year")
pyplot.ylabel("oil volume")
pyplot.title('ACtual vs poly regression forecast of oil production for bore:5599')

y_testfinal5599=y_test_5599['BORE_OIL_VOL']
print('R2 Value of Linear regression in Volume in 5693:',L_reg.score(x_testfinal5599,y_testfinal5599))
print('R2 value of poly regression(d-4) prediction for Bore:5599 =',l_reg.score(p_x_test5599,y_testfinal5599))
# Out:
# R2 Value of Linear regression in Volume in 5693: 0.55008329388721
# R2 value of poly regression(d-4) prediction for Bore:5599 = 0.9489500044347976

# %%
#planning linear regression for w4:5351
x_test_5351=x_test[x_test['NPD_WELL_BORE_CODE']==5351]
y_test_5351=y_test[y_test["NPD_WELL_BORE_CODE"]==5351]

x_testfinal5351=x_test_5351.drop(['DATEPRD','NPD_WELL_BORE_CODE'],axis=1)

pred_y=L_reg.predict(x_testfinal5351)
#using pyplot style 'fivethirtyeight' to compare distribution
pyplot.style.use('fivethirtyeight')
pyplot.figure(figsize=(12,8))
pyplot.scatter(x_test_5351["DATEPRD"].tolist(),pred_y,label='predicted')
pyplot.scatter(x_test_5351["DATEPRD"].tolist(),y_test_5351['BORE_OIL_VOL'],label='actual')
pyplot.legend()
pyplot.xlabel("Year")
pyplot.ylabel("oil volume")
pyplot.title('Actual vs linear regression forecast of oil production for bore:5351')

y_testfinal5351=y_test_5351['BORE_OIL_VOL']
print('R2 Value of Linear regression in Volume in 5351:',L_reg.score(x_testfinal5351,y_testfinal5351))
# Out:
# R2 Value of Linear regression in Volume in 5351: 0.6750225210254903

# %%
#planning linear regression for w4:5351
x_test_5351=x_test[x_test['NPD_WELL_BORE_CODE']==5351]
y_test_5351=y_test[y_test["NPD_WELL_BORE_CODE"]==5351]

x_testfinal5351=x_test_5351.drop(['DATEPRD','NPD_WELL_BORE_CODE'],axis=1)

pred_y=L_reg.predict(x_testfinal5351)

#pol test 5351 regression values
p_x_test5351=p_reg.fit_transform(x_testfinal5351)
pol_y=l_reg.predict(p_x_test5351)

#using pyplot style 'fivethirtyeight' to compare distribution
pyplot.style.use('fivethirtyeight')
pyplot.figure(figsize=(12,8))
pyplot.scatter(x_test_5351["DATEPRD"].tolist(),pred_y,label='Linear predicted',color='blue')
pyplot.scatter(x_test_5351["DATEPRD"].tolist(),pol_y,label='Polynomial',color='red')

pyplot.scatter(x_test_5351["DATEPRD"].tolist(),y_test_5351['BORE_OIL_VOL'],label='actual',color='green')
pyplot.legend()
pyplot.xlabel("Year")
pyplot.ylabel("oil volume")
pyplot.title('ACtual vs poly regression forecast of oil production for bore:5351')

y_testfinal5351=y_test_5351['BORE_OIL_VOL']
print('R2 Value of Linear regression in Volume in 5351:',L_reg.score(x_testfinal5351,y_testfinal5351))
print('R2 value of poly regression(d-4) prediction for Bore:5351=',l_reg.score(p_x_test5351,y_testfinal5351))
# Out:
# R2 Value of Linear regression in Volume in 5351: 0.6750225210254903
# R2 value of poly regression(d-4) prediction for Bore:5351= 0.9354859563826239

# %%
#planning linear regression for w5:7078
x_test_7078=x_test[x_test['NPD_WELL_BORE_CODE']==7078]
y_test_7078=y_test[y_test["NPD_WELL_BORE_CODE"]==7078]

x_testfinal7078=x_test_7078.drop(['DATEPRD','NPD_WELL_BORE_CODE'],axis=1)

pred_y=L_reg.predict(x_testfinal7078)
#using pyplot style 'fivethirtyeight' to compare distribution
pyplot.style.use('fivethirtyeight')
pyplot.figure(figsize=(12,8))
pyplot.scatter(x_test_7078["DATEPRD"].tolist(),pred_y,label='predicted')
pyplot.scatter(x_test_7078["DATEPRD"].tolist(),y_test_7078['BORE_OIL_VOL'],label='actual')
pyplot.legend()
pyplot.xlabel("Year")
pyplot.ylabel("oil volume")
pyplot.title('Actual vs linear regression forecast of oil production for bore:7078')

y_testfinal7078=y_test_7078['BORE_OIL_VOL']
print('R2 Value of Linear regression in Volume in 7078:',L_reg.score(x_testfinal7078,y_testfinal7078))
# Out:
# R2 Value of Linear regression in Volume in 7078: -3.014053751126795

# %%
#planning linear regression for w5:7078
x_test_7078=x_test[x_test['NPD_WELL_BORE_CODE']==7078]
y_test_7078=y_test[y_test["NPD_WELL_BORE_CODE"]==7078]

x_testfinal7078=x_test_7078.drop(['DATEPRD','NPD_WELL_BORE_CODE'],axis=1)

pred_y=L_reg.predict(x_testfinal7078)

#pol test 7078 regression values
p_x_test7078=p_reg.fit_transform(x_testfinal7078)
pol_y=l_reg.predict(p_x_test7078)

#using pyplot style 'fivethirtyeight' to compare distribution
pyplot.style.use('fivethirtyeight')
pyplot.figure(figsize=(12,8))
pyplot.scatter(x_test_7078["DATEPRD"].tolist(),pred_y,label='Linear predicted',color='blue')
pyplot.scatter(x_test_7078["DATEPRD"].tolist(),pol_y,label='Polynomial',color='red')

pyplot.scatter(x_test_7078["DATEPRD"].tolist(),y_test_7078['BORE_OIL_VOL'],label='actual',color='green')
pyplot.legend()
pyplot.xlabel("Year")
pyplot.ylabel("oil volume")
pyplot.title('Actual vs poly regression forecast of oil production for bore:7078')

y_testfinal7078=y_test_7078['BORE_OIL_VOL']
print('R2 Value of Linear regression in Volume in 7078:',L_reg.score(x_testfinal7078,y_testfinal7078))
print('R2 value of poly regression(d-4) prediction for Bore 7078=',l_reg.score(p_x_test7078,y_testfinal7078))
# Out:
# R2 Value of Linear regression in Volume in 7078: -3.014053751126795
# R2 value of poly regression(d-4) prediction for Bore 7078= 0.3236406446206057

# %%
print('R2 value poly regression(d-4) forecast for Bore:5599 =',l_reg.score(p_x_test5599,y_testfinal5599))

print('R2 value poly regression(d-4) forecast for Bore:5351=',l_reg.score(p_x_test5351,y_testfinal5351))

print('R2 value poly regression(d-4) forecast for Bore 7078=',l_reg.score(p_x_test7078,y_testfinal7078))
